# %% [markdown]
# <a href="https://colab.research.google.com/github/frasercrichton/ai-dde-hackthon/blob/feature%2Fleiden-guidelines-doc/RAG.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from google.colab import userdata
userdata.get('GITHUB_TOKEN')

# !git clone https://{GITHUB_TOKEN}@github.com/frasercrichton/ai-dde-hackthon.git
# %cd ai-dde-hackthon
! git checkout feature/leiden-guidelines-doc
# %cd team-red
! ls
# %poetry install

# %%
import sys
from pathlib import Path

cwd = Path.cwd()
project_root = f'{cwd.parent}' 

sys.path.append(project_root)

print('The project directory is:', project_root)
print('The working directory is:', cwd)
# Out:
# The project directory is: /Users/frasercrichton/Development/ai-dde-hackthon/team-red
# The working directory is: /Users/frasercrichton/Development/ai-dde-hackthon/team-red/notebooks

# %%
import logging

for handler in logging.root.handlers[:]:
    logging.root.removeHandler(handler)

logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(name)s - %(message)s',
    datefmt='%Y-%m-%d %H:%M:%S'
)
# 
# self.logger = logging.getLogger(self.__class__.__name__)

logger = logging.getLogger(__name__)

# %%
def load_pdf(file_path):
    reader = PdfReader(file_path)
    text = '\n'.join([page.extract_text() for page in reader.pages])
    return text

# %%
from typing import Dict, List, Tuple
from langchain_text_splitters import RecursiveCharacterTextSplitter
import re



def debug(self, documents, number_of_documents=5):
    for doc in documents:
        print(f'\n{'=' * 50}')
        print(f'Section: {doc[:100]}')
        print('-' * 50)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[61], line 112
#     110 # Usage
#     111 pdf_text = load_pdf('../data/Leiden Guidelines on the Use of DDE in ICCTs_20220404.pdf')
# --> 112 documents = process_document(pdf_text)
#     114 # Verify
#     116 x = LeidenGuidelinesSplitter().split_text_with_metadata(pdf_text)
#
# Cell In[61], line 86, in process_document(text)
#      84 text = clean_text(text)
#      85 splitter = LeidenGuidelinesSplitter()
# ---> 86 chunks = splitter.split_text(text)
#      88 documents = []
#      89 current_section = ''
#
# Cell In[61], line 68, in LeidenGuidelinesSplitter.split_text(self, text)
#      67 def split_text(self, text):
# ---> 68     return [chunk for chunk, _ in self._split_text_with_metadata(text)]
#
# Cell In[61], line 40, in LeidenGuidelinesSplitter._split_text_with_metadata(self, text)
#      37 chunks_with_metadata = []
#      39 # First split by major sections
# ---> 40 sections = self._split_by_separator(text, self._get_legal_separators()[0])
#      42 for section in sections:
#      43     # Extract section header if present
#      44     if '\n' in section and section.split('\n')[0].strip() == '':
#
# AttributeError: 'LeidenGuidelinesSplitter' object has no attribute '_split_by_separator'
